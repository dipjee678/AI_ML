# %% [markdown]
# Registered email : dipjee678@gmail.com

# %%
# You must run this code and use this dataset for all questions

import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# ## NumPy — 5 Questions

# %% [markdown]
# # Q1 Answer

# %%
print(emp_ages)
print(emp_income)


print("Data Type:")
print(emp_ages.dtype)
print(emp_income.dtype)


print("Number of Dimensions:")
print(emp_ages.ndim)
print(emp_income.ndim)


print("Shape:")
print(emp_ages.shape)
print(emp_income.shape)


print("Total Number of Elements:")
print(emp_ages.size)
print(emp_income.size)
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# [51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]
# Data Type:
# int64
# int64
# Number of Dimensions:
# 1
# 1
# Shape:
# (50,)
# (50,)
# Total Number of Elements:
# 50
# 50

# %% [markdown]
# # Q2 Answer

# %%
max_salary = np.max(emp_income)
print("Maximum Salary:", max_salary)

min_salary = np.min(emp_income)
print("Minimum Salary:", min_salary)


avg_salary = np.mean(emp_income)
print("Average Salary:", avg_salary)


avg_age = np.mean(emp_ages)
print("Average Age:", avg_age)
# Out:
# Maximum Salary: 94722
# Minimum Salary: 35452
# Average Salary: 68409.48
# Average Age: 35.44

# %% [markdown]
# # Q3 Answer

# %%
filtered_ages = emp_ages[(emp_ages >= 25) & (emp_ages <= 40)]
filtered_salaries = emp_income[emp_income > 50000]

print("Filtered Ages:", filtered_ages)
print("Filtered Salaries:", filtered_salaries)


count = np.count_nonzero(filtered_ages) + np.count_nonzero(filtered_salaries)
print("satisfied employees :", count)
# Out:
# Filtered Ages: [37 37 35 38 31 35 29 38 27 32 26 37 26 30 30 27 25 39 31]
# Filtered Salaries: [51725 82295 72187 58915 76159 92864 76155 90494 68641 56879 83682 94722
#  91041 68744 63187 74146 75641 76760 78354 60584 79898 59682 71888 51086
#  73700 82550 71447 76100 72269 73314 87428 94427 84188 52013 63326 59500
#  55523 58602 90794 82331 73048 59727 50398]
# satisfied employees : 62

# %% [markdown]
# # Q4 Answer

# %%
avg_age = np.mean(emp_ages)

updated_ages = []

for age in emp_ages:
    if age < avg_age:
        updated_ages.append(age + 4)
    else:
        updated_ages.append(age + 2)

new_emp_ages = np.array(updated_ages)


print("Original Ages:", emp_ages)
print("Updated Ages:", new_emp_ages)
print("Average Age Used:", avg_age)
# Out:
# Original Ages: [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# Updated Ages: [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# Average Age Used: 35.44

# %% [markdown]
# # Q5 Answer

# %%
tech_roles = ["Software Developer", "Backend Developer"]

old_total = sum(emp_income)

new_salary = emp_income.copy()

for i in range(len(emp_roles)):
    if emp_roles[i] in tech_roles:
        new_salary[i] = new_salary[i] + (new_salary[i] * 0.08)

new_total = sum(new_salary)

increase = new_total - old_total

print("Old Total Salary:", old_total)
print("New Total Salary:", new_total)
print("Overall Increase:", increase)
# Out:
# Old Total Salary: 3420474
# New Total Salary: 3490239
# Overall Increase: 69765

# %% [markdown]
# # Q6 Answer

# %%
data = pd.read_csv("staff_data.csv")

print("First 3 Rows:")
print(data.head(3))

print("Dataset Info:")
print(data.info())

print("Summary Statistics:")
print(data.describe())
# Out:
# First 3 Rows:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
# None
# Summary Statistics:
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# ...

# %% [markdown]
# # Q7 Answer

# %%
filtered_data = data[["emp_id", "emp_age", "role"]]

filtered_data = filtered_data[(filtered_data["emp_age"] >= 25) & (filtered_data["emp_age"] <= 40)]


filtered_data = filtered_data.sort_values('emp_id')


print(filtered_data.tail(3))
# Out:
#     emp_id  emp_age                 role
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %% [markdown]
# # Q8 Answer

# %%
hr_data = data.loc[(data['role'] == 'HR Executive') | (data['role'] == 'HR Manager')]

print("HR Employees:")
print(hr_data)

count = len(hr_data)
print("Total HR Employees:", count)
# Out:
# HR Employees:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# Total HR Employees: 9

# %% [markdown]
# # Q9 Answer

# %%
sorted_data = data.sort_values(["emp_age", "emp_salary"], ascending=[1, 0])


result = sorted_data[["emp_id", "role", "emp_salary"]]

print(result.head(5))
# Out:
#     emp_id                role  emp_salary
# 30     131     Sales Executive       82550
# 18     119  Software Developer       63187
# 41     142    Digital Marketer       59500
# 2      103  Operations Manager       35452
# 36     137     Sales Executive       94427

# %% [markdown]
# # Q10 Answer

# %%
df = data.copy()

df["previous_salary"] = df["emp_salary"]
df["new_salary"] = df["emp_salary"].astype(float)   # fix dtype

for i in range(len(df)):
    if df.loc[i, "role"] == "Software Developer" or df.loc[i, "role"] == "Backend Developer":
        df.loc[i, "new_salary"] = df.loc[i, "emp_salary"] * 1.12
    else:
        df.loc[i, "new_salary"] = df.loc[i, "emp_salary"] * 1.05

df["increase_of_salary"] = df["new_salary"] - df["previous_salary"]

print(df[["role", "previous_salary", "new_salary", "increase_of_salary"]])
# Out:
#                    role  previous_salary  new_salary  increase_of_salary
# 0            HR Manager            51725    54311.25             2586.25
# 1            Accountant            38495    40419.75             1924.75
# 2    Operations Manager            35452    37224.60             1772.60
# 3      Digital Marketer            82295    86409.75             4114.75
# 4     Backend Developer            72187    80849.44             8662.44
# 5            HR Manager            58915    61860.75             2945.75
# 6     Backend Developer            76159    85298.08             9139.08
# 7       Sales Executive            92864    97507.20             4643.20
# 8       Sales Executive            76155    79962.75             3807.75
# 9          HR Executive            90494    95018.70             4524.70
# 10    Backend Developer            68641    76877.92             8236.92
# 11  Marketing Executive            48079    50482.95             2403.95
# ...
